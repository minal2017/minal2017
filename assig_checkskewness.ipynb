# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dict={"class Marks":[61,64,67,70,73],"Frequency":[5,18,42,27,8]}

# %%
df_num=pd.DataFrame(dict)
print(df_num)
# Out:
#    class Marks  Frequency
# 0           61          5
# 1           64         18
# 2           67         42
# 3           70         27
# 4           73          8

# %%
df_num.columns
# Out:
# Index(['class Marks', 'Frequency'], dtype='object')

# %%
from scipy.stats import skew

# %%
for col in df_num:
    print(col)
    print(skew(df_num[col]))
    #visualize either data normally distrubuted or not
    sns.distplot(df_num[col])
    plt.show()
# Out:
# class Marks
# 0.0
# Frequency
# 0.48213652316578415
